# %% [markdown]
# <div style="border:solid green 3px; padding: 20px">
# <b>🥇 Дмитрий, спасибо за доработки, проект принят, молодец!</b>
#
# Ты провел отличную работу над ошибками! Уверен, ты обязательно достигнешь своей цели! Успехов в дальнейшем обучении! 🙂

# %% [markdown]
# Дмитрий, привет! Меня зовут Ефимов Денис и сегодня я буду делать ревью твоего проекта!\
# В Практикуме принято общаться на "ты", однако если это неудобно - дай знать, и можем перейти на более официальное общение.
#
# Ниже ты найдешь мои комментарии - пожалуйста, не перемещай, не изменяй и не удаляй их. Я буду использовать цветовую разметку:
#
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера:</b> Если все сделано хорошо. </div>
#
# <div class="alert alert-block alert-warning">
# <b>🔁Комментарий ревьюера:</b> Некритичное замечание; если таких замечаний меньше трех — проект может быть принят без их отработки.</div>
#
# <div class="alert alert-block alert-danger">
# <b>❌Комментарий ревьюера:</b> Грубая ошибка, необходимо исправить, иначе проект не будет принят.
# </div>
#
# Давай работать над проектом в диалоге: если ты что-то меняешь в проекте или отвечаешь на мои комментарии — пиши об этом. Мне будет легче отследить изменения, если ты выделишь свои комментарии:
# Например так:
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
# Hello World! ✔
# </div>
#
# Или можешь использовать эту галочку ✔ в моих комментариях, если писать особо нечего.
#
# <div class="alert alert-block alert-warning">
# <b>Общее впечатление:</b>
#
# - Ты проделал огромную работу и проект получился впечатляющим:)
# - У меня есть несколько замечаний, исправив которые ты сделаешь проект еще лучше.
# - Пробегись по моим комментариям, исправь недочёты и всё будет отлично :)
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>КОММЕНТАРИЙ СТУДЕНТА:</b> Здравствуй. Мозг кипит, Юпитер отваливается - проверять и приводить в красивый вид буду позже. Посмотри, пожалуйста, критичные замечания и вообще насколько вектор размышлений правильный. Я подумаю над выводами.
# https://www.kaggle.com/code смотрю примеры работ, вызывает уважение. Из-за отсутствия времени и опыта мой проект пока не такой красивый, но я понял к чему стремиться =)
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера:</b> Молодец, что ищешь ориентиры и стремишься к ним!  </div>

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# <div> В вашем распоряжении данные сервиса Яндекс.Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктов за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые — получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.
#
# Цель исследования - выяснить параметры, влияющие на цену недвижимости в городе Санкт-Петербург.
#
# Отдельные вопросы, подлежащие изучению:
# + Сколько времени в среднем уходит на продажу квартиры?
# + Когда продажу можно назвать быстрой / необычно долгой?
# + Какие факторы больше всего влияют на общую (полную) стоимость объекта?
# + Как стоимость объектов зависит от расстояния до центра города?
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера:</b> Молодец, что написал введение!  </div>

# %% [markdown]
# ### Откройте файл с данными и изучите общую информацию.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('/datasets/real_estate_data.csv', sep='\t' )

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>🔁Комментарий ревьюера:</b>
#
# Импорт всех библиотек лучше делать в одной отдельной ячейке, чтобы при необходимости можно было ее перезапустить без влияния на другой код и без перезаписи датасета. </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
# Исправлено ✔
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %%
data.head(10)
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0      108.00  2019-03-07T00:00:00      3
# 1             7   3350000.0       40.40  2018-12-04T00:00:00      1
# 2            10   5196000.0       56.00  2015-08-20T00:00:00      2
# 3             0  64900000.0      159.00  2015-07-24T00:00:00      3
# 4             2  10000000.0      100.00  2018-06-19T00:00:00      2
# 5            10   2890000.0       30.40  2018-09-10T00:00:00      1
# 6             6   3700000.0       37.30  2017-11-02T00:00:00      1
# 7             5   7915000.0       71.60  2019-04-18T00:00:00      2
# 8            20   2900000.0       33.16  2018-05-23T00:00:00      1
# 9            18   5400000.0       61.00  2017-02-26T00:00:00      3
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0        51.00      8          NaN  ...
# 1             NaN          11.0        18.60      1          NaN  ...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %% [markdown]
# Видим 23699 строк разной степени заполненности.
# Указаны названия столбцов, в описании задания хранится расшифровка каждого из них, они соответствуют и значит мне прислали верный файл.

# %%
data.hist(figsize = (15,15));

# %% [markdown]
# Гистограммы на первый взгляд выглядят адекватно, имеют распределения, проименованы.

# %% [markdown]
# Вывод: полученная база данных открылась, работает, поддается описанию.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>❌Комментарий ревьюера:</b>
#
# Каждому пункту нужен вывод.
#
# Что мы можем сказать о данных после первичного знакомства  с ними?
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
# Выводы добавлены, база данных осмотрена ✔
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %% [markdown]
# ### Предобработка данных

# %%
print(data.isnull().sum()) #количество пропусков по каждому столбцу
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9195
# floors_total               86
# living_area              1903
# floor                       0
# is_apartment            20924
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# cityCenters_nearest      5519
# parks_around3000         5518
# parks_nearest           15620
# ponds_around3000         5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64

# %%
data = data.rename(columns={'cityCenters_nearest':'city_centers_nearest'}) 
#переименовал "cityCenters_nearest" в корректный вид

# %% [markdown]
# # 2.1 Обработка пропусков

# %%
data['ceiling_height'].isna().sum()
# Out:
# 9195

# %% [markdown]
# Первый столбец с пропусками - "ceiling_height", означающий высоту потолков. Важный и однозначный параметр.
# 9195 пропусков. Заменяю на медианные значения.

# %%
data['ceiling_height'] = data['ceiling_height'].fillna(data['ceiling_height'].median())
data['ceiling_height'].isna().sum()
# Out:
# 0

# %%
data.head(5)
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0  2019-03-07T00:00:00      3
# 1             7   3350000.0        40.4  2018-12-04T00:00:00      1
# 2            10   5196000.0        56.0  2015-08-20T00:00:00      2
# 3             0  64900000.0       159.0  2015-07-24T00:00:00      3
# 4             2  10000000.0       100.0  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0         51.0      8          NaN  ...
# 1            2.65          11.0         18.6      1          NaN  ...
# 2            2.65           5.0         34.3      4          NaN  ...
# 3            2.65          14.0          NaN      9          NaN  ...
# 4            3.03          14.0         32.0     13          NaN  ...
#
#    kitchen_area  balcony    locality_name  airports_nearest  \
# 0          25.0      NaN  Санкт-Петербург           18863.0
# ...

# %%
data.dropna(subset=['floors_total'], inplace=True)

# %%
data['living_area'].describe()
# Out:
# count    21743.000000
# mean        34.462781
# std         22.037433
# min          2.000000
# 25%         18.600000
# 50%         30.000000
# 75%         42.300000
# max        409.700000
# Name: living_area, dtype: float64

# %%
data['living_k'] = data['living_area'] / data['total_area'] #созданы 2 столбца для подсчёта коэффициентов отношения 
data['kitchen_k'] = data['kitchen_area'] / data['total_area'] #всей площади к жилой и площади кухни
print(data['living_k'].median()) #медиана по коэффициенту жилой площади = 0.56
print(data['kitchen_k'].median()) #медиана по коэффициенту кухни = 0.17
# Out:
# 0.5681818181818182
# 0.1723476871686878

# %%
data['kitchen_area'] = data['kitchen_area'].fillna(data['total_area'] * 0.17) #заполняем пропуски, помножив общую площадь на коэффициент
data['living_area'] = data['living_area'].fillna(data['total_area'] * 0.57)

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>🔁Комментарий ревьюера 2:</b>
#
# Тут лучше прописывать не значения 0.17 и 0.57, а использовать переменные, в которые предварительно сохранить результат работы метода median(). Таким образом не придется вносить корректировки вручную при изменении или пополнении набора данных.    </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>❌Комментарий ревьюера:</b>
#
# Не нужно стремиться заполнить все пропуски (особенно просто медианой), они иногда сами по себе несут ценную информацию.
#
# Теперь подробнее по столбцам:
#
#  - **'floors_total'**. При таком заполнении пропусков мы получаем квартиры, у которых этаж расположения находится выше общего количества этажей в доме. Строк с пропусками в этом столбце немного, поэтому их можно просто исключить.
#
#  - **'living_area'** и **'kitchen_area'**. У нас в данных абсолютно разные квартиры из разных населенных пунктов. Есть как студии и однокомнатные с маленькой площадью, так и многокомнатные квартиры большой площади, их площади уравнивать неправильно. Пропуски можно заполнить так: сначала вычисляем среднее отношение жилой площади к общей, это будет наш коэффициент жилой площади. Далее в строках с пропусками умножаем общую площадь на этот коэффициент, получая жилую площадь. Подобным образом можно заполнить пропуски и в столбце с площадью кухни.
#
#  - **'parks_nearest', 'ponds_nearest', 'parks_around3000', 'ponds_around3000'**. Обрати внимание на то, что эти значения  получены автоматически на основе картографических данных. А если данные не получены, то скорее всего объекта рядом нет (пруды и парки) или до объекта слишком далеко и эту информацию нельзя получить (а значит она и не будет иметь значения при исследовании) . А заполняя пропуски медианой, мы переносим квартиры и сажаем рядом парки и выкапываем пруды)) Это неправильно. Лучше в таком случае оставить пропуски как есть.
#
#  - **'airports_nearest', 'city_centers_nearest'**. Тут ситауция схожая, во всех ли населенных пунктах должны быть эти объекты?
#
#  - **'days_exposition'**. Заполнять пропуски в количестве дней размещения некорректно, они означают ,что объявления были активны на момент выгрузки, то есть квартиры не были проданы. А заполняя пропуски мы делаем эти квартиры "проданными", это повлияет на результаты исследования.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
# Я подозревал, что это не лучшая идея, но мозг куда-то ушёл погулять в этот момент. Мне смешно, что я сам себя обманул и по медианным значениям потом строил графики и указывал пики. И floors_total - медианное значение, которое больше реальной этажности дома)
# floors_total удалены, living_area и kitchen_area считаются,  остальные оставлены ✔
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %%
data['kitchen_area'].describe()
# Out:
# count    23613.000000
# mean        10.475906
# std          6.020408
# min          1.300000
# 25%          7.000000
# 50%          9.000000
# 75%         12.000000
# max        112.000000
# Name: kitchen_area, dtype: float64

# %%
data['living_area'].describe()
# Out:
# count    23613.000000
# mean        34.596785
# std         22.362852
# min          2.000000
# 25%         19.000000
# 50%         30.000000
# 75%         42.100000
# max        409.700000
# Name: living_area, dtype: float64

# %%
data['living_area'].isna().sum()
# Out:
# 0

# %%
data['kitchen_area'].isna().sum()
# Out:
# 0

# %%
print(data.isna().sum())
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height              0
# floors_total                0
# living_area                 0
# floor                       0
# is_apartment            20838
# studio                      0
# open_plan                   0
# kitchen_area                0
# balcony                 11480
# locality_name              48
# airports_nearest         5532
# city_centers_nearest     5509
# parks_around3000         5508
# parks_nearest           15568
# ponds_around3000         5508
# ponds_nearest           14552
# days_exposition          3172
# living_k                 1870
# kitchen_k                2231
# dtype: int64

# %% [markdown]
# Остались качественные пропуски в столбцах is_apartment, balcony, locality_name.
# Предположим, если в первом значение не указано, то наш параметр равен False.
# Незаполненный столбец с Балконами приравниваем к отсутствию балкона.
# locality_name можно или удалить или приравнять нулю - всего 48 строчек.

# %%
data['is_apartment'] = data['is_apartment'].fillna(False)
data['balcony'] = data['balcony'].fillna(value = 0)
data['locality_name'] = data['locality_name'].fillna(value = 'Неизвестно')

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера:</b>
#
# Тут все верно, только для неизвестного населенного пункта лучше так и написать "Неизвестно"</div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
# Переименовал в "Неизвестно" ✔
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b>👍  </div>

# %%
print(data.isna().sum())
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height              0
# floors_total                0
# living_area                 0
# floor                       0
# is_apartment                0
# studio                      0
# open_plan                   0
# kitchen_area                0
# balcony                     0
# locality_name               0
# airports_nearest         5532
# city_centers_nearest     5509
# parks_around3000         5508
# parks_nearest           15568
# ponds_around3000         5508
# ponds_nearest           14552
# days_exposition          3172
# living_k                 1870
# kitchen_k                2231
# dtype: int64

# %% [markdown]
# Основные пропуски убраны. Оставшиеся передавались автоматически на основе картографических данных.

# %% [markdown]
# # 2.2 Изменим тип данных

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23613 entries, 0 to 23698
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23613 non-null  int64
#  1   last_price            23613 non-null  float64
#  2   total_area            23613 non-null  float64
#  3   first_day_exposition  23613 non-null  object
#  4   rooms                 23613 non-null  int64
#  5   ceiling_height        23613 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           23613 non-null  float64
#  8   floor                 23613 non-null  int64
#  9   is_apartment          23613 non-null  bool
#  10  studio                23613 non-null  bool
#  11  open_plan             23613 non-null  bool
#  12  kitchen_area          23613 non-null  float64
#  13  balcony               23613 non-null  float64
#  14  locality_name         23613 non-null  object
# ...

# %% [markdown]
# Бросается в глаза - first_day_exposition тип Object, переведем в дату.
# balcony приведем в int - балконов может быть один, несколько, или его нет вообще.
# Некоторые float переводим в int, в базе нет значений с точностью до копейки в цене.

# %%
data['balcony'] = data['balcony'].astype(int)
data['last_price'] = data['last_price'].astype(int)
data['first_day_exposition'] = pd.to_datetime(data['first_day_exposition'],format='%Y-%m-%dT%H:%M:%S')
data['floors_total'] = data['floors_total'].astype(int)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23613 entries, 0 to 23698
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23613 non-null  int64
#  1   last_price            23613 non-null  int64
#  2   total_area            23613 non-null  float64
#  3   first_day_exposition  23613 non-null  datetime64[ns]
#  4   rooms                 23613 non-null  int64
#  5   ceiling_height        23613 non-null  float64
#  6   floors_total          23613 non-null  int64
#  7   living_area           23613 non-null  float64
#  8   floor                 23613 non-null  int64
#  9   is_apartment          23613 non-null  bool
#  10  studio                23613 non-null  bool
#  11  open_plan             23613 non-null  bool
#  12  kitchen_area          23613 non-null  float64
#  13  balcony               23613 non-null  int64
#  14  locality_name         23613 non-null  object
# ...

# %% [markdown]
# # 2.3 Проверим на дубликаты

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Явные дубликаты отсутствуют, но единственный столбец где хранятся названия может удивить.

# %%
set(data['locality_name'].unique())
# Out:
# {'Бокситогорск',
#  'Волосово',
#  'Волхов',
#  'Всеволожск',
#  'Выборг',
#  'Высоцк',
#  'Гатчина',
#  'Зеленогорск',
#  'Ивангород',
#  'Каменногорск',
#  'Кингисепп',
#  'Кириши',
#  'Кировск',
#  'Колпино',
#  'Коммунар',
#  'Красное Село',
#  'Кронштадт',
#  'Кудрово',
#  'Лодейное Поле',
#  'Ломоносов',
#  'Луга',
#  'Любань',
#  'Мурино',
#  'Неизвестно',
#  'Никольское',
#  'Новая Ладога',
#  'Отрадное',
#  'Павловск',
#  'Петергоф',
#  'Пикалёво',
#  'Подпорожье',
#  'Приморск',
#  'Приозерск',
#  'Пушкин',
#  'Санкт-Петербург',
#  'Светогорск',
#  'Сертолово',
#  'Сестрорецк',
#  'Сланцы',
#  'Сосновый Бор',
#  'Сясьстрой',
#  'Тихвин',
#  'Тосно',
#  'Шлиссельбург',
#  'городской поселок Большая Ижора',
#  'городской поселок Янино-1',
#  'городской посёлок Будогощь',
#  'городской посёлок Виллози',
#  'городской посёлок Лесогорский',
#  'городской посёлок Мга',
#  'городской посёлок Назия',
#  'городской посёлок Новоселье',
#  'городской посёлок Павлово',
# ...

# %% [markdown]
# Так и есть, удивительно. поселок и посёлок, городской посёлок и поселок городского типа... смысл один, объекты - разные.
# Привожу всё к однообразному виду - буквы е везде вместо ё, полностью убрать тип поселения из списка.

# %%
len(data['locality_name'].unique()) #количество всех уникальных названий
# Out:
# 365

# %%
data['locality_name'] = data['locality_name'].str.replace('ё','е') #ё на е меняем вне цикла, в любом случае

# %%
#parasites = ['село ', 'поселок ', 'деревня ','поселок городского типа ','городской поселок ','садоводческое некоммерческое товарищество ','коттеджный ','при железнодорожной станции ','станции ',]
data['locality_name'] = data['locality_name'].str.replace('поселок городского типа ','')
data['locality_name'] = data['locality_name'].str.replace('городской поселок ','')
data['locality_name'] = data['locality_name'].str.replace('деревня ','')
data['locality_name'] = data['locality_name'].str.replace('поселок ','')
data['locality_name'] = data['locality_name'].str.replace('садоводческое некоммерческое товарищество ','')
data['locality_name'] = data['locality_name'].str.replace('село ','')
data['locality_name'] = data['locality_name'].str.replace('коттеджный ','')
data['locality_name'] = data['locality_name'].str.replace('при железнодорожной станции ','')
data['locality_name'] = data['locality_name'].str.replace('станции ','')

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>🔁Комментарий ревьюера:</b>
#
# Заметил ли ты, что код повторяется? Тут лучше использовать цикл.</div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> ? </div>

# %%
len(data['locality_name'].unique())
# Out:
# 308

# %%
set(data['locality_name'].unique())
# Out:
# {'Агалатово',
#  'Александровская',
#  'Алексеевка',
#  'Аннино',
#  'Аро',
#  'Барышево',
#  'Батово',
#  'Бегуницы',
#  'Белогорка',
#  'Белоостров',
#  'Бокситогорск',
#  'Большая Вруда',
#  'Большая Ижора',
#  'Большая Пустомержа',
#  'Большие Колпаны',
#  'Большое Рейзино',
#  'Большой Сабск',
#  'Бор',
#  'Борисова Грива',
#  'Бугры',
#  'Будогощь',
#  'Ваганово',
#  'Важины',
#  'Вартемяги',
#  'Вахнова Кара',
#  'Вещево',
#  'Виллози',
#  'Вознесенье',
#  'Возрождение',
#  'Войсковицы',
#  'Войскорово',
#  'Володарское',
#  'Волосово',
#  'Волхов',
#  'Всеволожск',
#  'Выборг',
#  'Вырица',
#  'Выскатка',
#  'Высокоключевой',
#  'Высоцк',
#  'Гаврилово',
#  'Гарболово',
#  'Гатчина',
#  'Гладкое',
#  'Глажево',
#  'Глебычево',
#  'Глинка',
#  'Гончарово',
#  'Горбунки',
#  'Гостилицы',
#  'Громово',
#  'Дзержинского',
#  'Дружная Горка',
#  'Дружноселье',
#  'Дубровка',
#  'Елизаветино',
#  'Ефимовский',
#  'Жилгородок',
#  'Жилпоселок',
#  'Житково',
#  'Заводской',
# ...

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>🔁Комментарий ревьюера:</b>
#
# В этом пункте можно дополнительно сравнить количество неявных дубликатов до обработки названий населенных пунктов и после, чтобы увидеть результат проведенной работы. </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
# ✔
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %% [markdown]
# После обработки из 365 названий осталось 308, местами необычные типа "имени Свердлова", но в любом случае от дубликатов мы избавились.

# %% [markdown]
# # 2.4 Подсчёт аномалий в каждом столбце

# %%
data.describe()
# Out:
#        total_images    last_price    total_area         rooms  ceiling_height  \
# count  23613.000000  2.361300e+04  23613.000000  23613.000000    23613.000000
# mean       9.874518  6.540555e+06     60.340678      2.071147        2.724581
# std        5.681541  1.090172e+07     35.648988      1.078380        0.990085
# min        0.000000  1.219000e+04     12.000000      0.000000        1.000000
# 25%        6.000000  3.400000e+06     40.000000      1.000000        2.600000
# 50%        9.000000  4.650000e+06     52.000000      2.000000        2.650000
# 75%       14.000000  6.799000e+06     69.800000      3.000000        2.700000
# max       50.000000  7.630000e+08    900.000000     19.000000      100.000000
#
#        floors_total   living_area         floor  kitchen_area       balcony  \
# count  23613.000000  23613.000000  23613.000000  23613.000000  23613.000000
# mean      10.673824     34.596785      5.877313     10.475906      0.593063
# ...

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>КОММЕНТАРИЙ СТУДЕНТА:</b> Не удержался, использовал try-except. Предупреждает, что есть варианты оптимальнее, но мне нравится)
# </div>

# %%
for i in data.columns:
    try: 
        plt.figure()
        data.boxplot(i)
    except Exception: print('Не могу нарисовать диаграмму для столбца', i)
# Out:
# Не могу нарисовать диаграмму для столбца first_day_exposition
# Не могу нарисовать диаграмму для столбца locality_name
# /tmp/ipykernel_220/2756355652.py:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()

# %% [markdown]
# Наблюдаю основные аномалии в last_price, total_area, ceiling_height. Аномалии поменьше - в kitchen_area и total_area.

# %%
data.drop(index=data.query('last_price > 50000000').index,inplace=True)
data.drop(index=data.query('last_price < 200000').index,inplace=True)

# %%
data['last_price'].describe()
# Out:
# count    2.348100e+04
# mean     5.996783e+06
# std      4.973337e+06
# min      4.300000e+05
# 25%      3.400000e+06
# 50%      4.600000e+06
# 75%      6.700000e+06
# max      5.000000e+07
# Name: last_price, dtype: float64

# %%
data['total_area'].describe() #После чистки цены - пропали и аномально большие квартиры.
# Out:
# count    23481.000000
# mean        59.224394
# std         31.053971
# min         12.000000
# 25%         40.000000
# 50%         52.000000
# 75%         69.000000
# max        517.000000
# Name: total_area, dtype: float64

# %%
data['ceiling_height'].plot() 
data['ceiling_height'].describe()
#будем исходить из того, что 25 метров - это опечатка, означающая 2.5 метра. 
#Даже с учетом этой опечатки существуют значения сильно больше 6 метров, предлагаю удалить такие выбросы.
# Out:
# count    23481.000000
# mean         2.721792
# std          0.990941
# min          1.000000
# 25%          2.600000
# 50%          2.650000
# 75%          2.700000
# max        100.000000
# Name: ceiling_height, dtype: float64

# %%
data.drop(index=data.query('kitchen_area < 3').index,inplace=True)
data.drop(index=data.query('kitchen_area > 50').index,inplace=True)

# %%
data.drop(index=data.query('living_area < 5').index,inplace=True)

# %%
#temp_list=[]
#for i in data['ceiling_height']:
#    if 0 <=i < 2.5 or 6 <= i < 25 or 60 <= i <= 100: # всё что меньше 2,5 метров - удаляем. от 60 до 100 - удаляем. 
#        temp_list.append(None)
#    elif 25 <= i < 60: #Если предполагаем ошибку и в значении, например, 35 - делим на 10 = 3,5 и заносим в базу данных новое значение.
#        temp_list.append(i/10) 
#    else: temp_list.append(i)
#data['ceiling_height'] = temp_list
#data['ceiling_height'] = data['ceiling_height'].fillna(data['ceiling_height'].median())

data.update(data[(data['ceiling_height'] >= 25)]['ceiling_height']/10)
data.drop(index=data.query('ceiling_height < 2.5').index,inplace=True)
data.drop(index=data.query('ceiling_height > 6').index,inplace=True)
data['ceiling_height'].plot();

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>🔁Комментарий ревьюера:</b>
#
# Циклы к датафрейму лучше не применять, они будут очень долго работать на больших данных. Поделить на 10 можно немного проще:</div>
#
#
# ```python
#
#
#                 df.loc[df['ceiling_height'] > 25, 'ceiling_height'] /= 10
#
# ```
#
# <div class="alert alert-block alert-warning">
#
#
# А затем с помощью срезов отсечь оставшиеся аномальные значения.</div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
# Убрал цикл
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %%
data['ceiling_height'].describe()
# Out:
# count    23339.000000
# mean         2.694710
# std          0.211739
# min          2.500000
# 25%          2.600000
# 50%          2.650000
# 75%          2.700000
# max          5.800000
# Name: ceiling_height, dtype: float64

# %% [markdown]
# Результат работы с аномалиями - основные выбросы удалены. Предобработка данных завершена.

# %%
# код ревьюера
data.describe()
# Out:
#        total_images    last_price    total_area         rooms  ceiling_height  \
# count   23339.00000  2.333900e+04  23339.000000  23339.000000    23339.000000
# mean        9.85972  5.977310e+06     59.087649      2.055915        2.694710
# std         5.66823  4.902070e+06     30.273699      1.052158        0.211739
# min         0.00000  4.300000e+05     17.000000      0.000000        2.500000
# 25%         6.00000  3.400000e+06     40.000000      1.000000        2.600000
# 50%         9.00000  4.600000e+06     52.000000      2.000000        2.650000
# 75%        14.00000  6.700000e+06     69.000000      3.000000        2.700000
# max        50.00000  5.000000e+07    517.000000     19.000000        5.800000
#
#        floors_total   living_area         floor  kitchen_area       balcony  \
# count  23339.000000  23339.000000  23339.000000  23339.000000  23339.000000
# mean      10.707571     33.896293      5.885899     10.276987      0.593384
# ...

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>🔁Комментарий ревьюера:</b>
#
# А может ли быть кухня 1.3 кв.м.? А жилая площадь 2 кв.м.? Какое максимальное количество этажей в жилых домах Ленинградской области? </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
# Удивительно) сейчас прочёл про максимальные этажности. Оказалось, что максимум из существующих - 29 этажей. И в 2021 был закон о строительстве новых домов не выше 12 этажей. Не знаю правда ли ввели в действие этот закон, или он так и остался газетным заголовком. Для Москвы 60 этажей выглядят нормой.
# Про площади согласен, убираю жилые площади меньше 5 метров и кухни меньше 3 и больше 50м.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Для Москвы 60 этажей выглядят нормой, но у нас данные по Ленинградской области)  </div>

# %% [markdown]
# ### Посчитайте и добавьте в таблицу новые столбцы

# %% [markdown]
# Добавим следующие столбцы в датафрейм:
#
#     цена квардратного метра - 'sqm_price'
#
#     день публикации объявления - 'day_expo'
#
#     месяц публикации - 'month_expo'
#
#     год публикации - 'year_expo'
#
#     расстояние в км до центра города - 'center_distance_km'
#
#     тип этажа квартиры - 'floor_type' (первый, последний, другой) - напишем через отдельную функцию и метод .apply()

# %%
data['sqm_price'] = data['last_price']/data['total_area']
data['day_expo'] = data['first_day_exposition'].dt.dayofweek # понедельник = 0, воскресенье = 6.
data['year_expo'] = data['first_day_exposition'].dt.year
data['month_expo'] = data['first_day_exposition'].dt.month
data['center_distance_km'] = round(data['city_centers_nearest']/1000) #приводим метры к километрам и округляем

# %%
def level(row):
    all_level = row['floors_total']
    level = row['floor']
    if all_level == level:
        row['floor_type'] = 'последний'
        return row
    elif level == 1:
        row['floor_type'] = 'первый'
        return row
    else:
        row['floor_type'] = 'другой'
        return row
    
data = data.apply(level, axis=1)

# %%
data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20    13000000       108.0           2019-03-07      3
# 1             7     3350000        40.4           2018-12-04      1
# 2            10     5196000        56.0           2015-08-20      2
# 4             2    10000000       100.0           2018-06-19      2
# 5            10     2890000        30.4           2018-09-10      1
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0            2.70            16         51.0      8         False  ...
# 1            2.65            11         18.6      1         False  ...
# 2            2.65             5         34.3      4         False  ...
# 4            3.03            14         32.0     13         False  ...
# 5            2.65            12         14.4      5         False  ...
#
#    ponds_nearest  days_exposition  living_k  kitchen_k      sqm_price  \
# ...

# %% [markdown]
# Вывод: Добавлены столбцы с параметрами, которые, возможно, помогут в расчётах и ответах на поставленные задачи. Для расчёта типа этажа написана не сложная функция.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>❌Комментарий ревьюера:</b>
#
# После этапа предобработки также нужно сделать краткий резюмирующий вывод о проделанной работе.</div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
#  ✔
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %% [markdown]
# ### Проведите исследовательский анализ данных

# %%
data.hist(figsize=(25,25));

# %%
data['total_area'].plot(kind='hist', range=(0,100)).set_title('Распределение общей площади');
plt.xlabel("Площадь в кв.метрах");
plt.ylabel("Количество квартир");

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>❌Комментарий ревьюера:</b>
#
# Необходимо подписывать каждый график и оси на нем для удобства восприятия. Есть [хорошая статья](https://devpractice.ru/matplotlib-lesson-3-3-text-elements/), которая подскажет как это правильно сделать)</div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
# Подписал всё.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %% [markdown]
# Самые популярные квартиры среди объявлений площадью от 30 до 50 метров.

# %%
data['last_price'].plot(kind='hist', range=(400000,15000000)).set_title('Распределение по стоимости');
plt.xlabel("Стоимость");
plt.ylabel("Количество квартир");

# %% [markdown]
# Большинство квартир стоимостью около 5 миллионов рублей

# %%
data['living_area'].plot(kind='hist', range=(0,100)).set_title('Распределение по жилой площади');
plt.xlabel("Жилая площадь, кв.м.");
plt.ylabel("Количество квартир");

# %% [markdown]
# 2 пика по площадям говорят за большое количество студий до 20 квадратных метров, и квартир 30-40 квадратных метров.

# %%
data['kitchen_area'].plot(kind='hist', range=(0,30)).set_title('Распределение по площади кухни');
plt.xlabel("Площадь кухни, кв.м.");
plt.ylabel("Количество квартир");

# %% [markdown]
# Размер кухни в большинстве квартир около 10 квадратных метров.

# %%
data['rooms'].plot(kind='hist', range=(0,5)).set_title('Распределение по комнатам');
plt.xlabel("Количество комнат");
plt.ylabel("Количество квартир");

# %% [markdown]
# Вполне закономерная картина, что большинство квартир - 1- и 2-хкомнатные, меньше 3х-комнтаных.

# %%
data['ceiling_height'].plot(kind='hist', range=(2,5)).set_title('Распределение по высоте потолков');
plt.xlabel("Высота потолка, м.");
plt.ylabel("Количество квартир");

# %% [markdown]
# Высота потолков в квартирах чаще всего не больше 3х метров, в среднем - 2.65.

# %%
data['floor'].plot(kind='hist', range=(0,15)).set_title('Распределение по этажам');
plt.xlabel("Этаж");
plt.ylabel("Количество квартир");

# %% [markdown]
# Вероятно, большое количество объявлений среди вторичного фонда - в пятиэтажках, и не выше 5го этажа.

# %%
data['floor_type'].value_counts().plot.bar();
plt.ylabel("Количество квартир");

# %% [markdown]
# Очевидно, объявлений о продаже между первым и последним этажами абсолютное большинство.

# %%
data['floors_total'].plot(kind='hist', range=(0,20)).set_title('Распределение по этажности дома');
plt.xlabel("Этажность дома");
plt.ylabel("Количество квартир");

# %% [markdown]
# Похожий вывод, что большинство объявлений - про пятиэтажки.

# %%
data['city_centers_nearest'].plot(kind='hist', range=(0,20000)).set_title('Распределение по удалённости от центра');
plt.xlabel("Удаленность от центра, м.");
plt.ylabel("Количество квартир");

# %% [markdown]
# Большинство квартир продаётся в районе КАД - 10-13 км от центра города.

# %%
data['airports_nearest'].plot(kind='hist', range=(0,40000)).set_title('Распределение по удаленности от аэропорта');
plt.xlabel("Удаленность от аэропорта.");
plt.ylabel("Количество квартир");

# %% [markdown]
# Вокруг Петербурга находятся 2 аэропорта - Пулково и Левашово, оба достаточно далеко от центра и от большинства продающихся квартир.

# %%
data['parks_nearest'].plot(kind='hist', range=(0,1500)).set_title('Распределение по удаленности от парков');
plt.xlabel("Удаленность от парка");
plt.ylabel("Количество квартир");

# %% [markdown]
# Большое количество парков и зелени в городе сказываются на статистике - много квартир расположено в пешей доступности от парка.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>🔁Комментарий ревьюера:</b>
#
# Тут стоит уточнить ,что это касается квартир, у которых этот параметр заполнен, потому что их доля невелика. Странно смотрится пик на значении, которым были заполнены пропуски)</div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔁Комментарий студента:</b>
# Спасибо за замечание. Пик, которому я сам присвоил медианное значение меня совершенно не смутил =(
# После корректной предобработки пик пропал
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %%
data['day_expo'].value_counts().sort_index(ascending=True).plot.bar();
plt.xlabel("День недели, где 0 - понедельник");
plt.ylabel("Количество квартир");

# %% [markdown]
# Очевидно, большинство объявлений опубликовано в рабочие дни.

# %%
data['month_expo'].value_counts().sort_index(ascending=True).plot.bar();
plt.xlabel("Месяц");
plt.ylabel("Количество квартир");

# %% [markdown]
# Пик объявлений - февраль, март и апрель. В мае объявлений меньше всего.

# %% [markdown]
# Проанализированы основные параметры.

# %% [markdown]
# # 4.1 Как быстро продавались квартиры?

# %%
data['days_exposition'].hist(bins = 50, range=(0,365)).set_title('Продолжительность объявления');
plt.xlabel("Количество дней");
plt.ylabel("Количество квартир");
data['days_exposition'].describe()
# Out:
# count    20213.000000
# mean       180.285311
# std        219.402875
# min          1.000000
# 25%         45.000000
# 50%         95.000000
# 75%        230.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %% [markdown]
# Вывод: Медиана приходится на срок 3 месяца. Вероятно, это время нужно для проверки документов, подписания договоров.
# Часть квартир продается за 1.5 месяца, а среднее значение - 6 месяцев.
# Исходя из таких данных можно сделать вывод, что продажа квартиры за 1 месяц считается очень быстрой, а за 6 месяцев и более - долгими.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера:</b>
#
# В приницпе верно, только пик объясняется заполнением пропусков)</div>

# %% [markdown]
# # 4.2 Какие факторы больше всего влияют на общую (полную) стоимость объекта?

# %%
print(data['last_price'].corr(data['total_area'])) #без print не срабатывает .corr
data.plot(x='last_price', y='total_area', kind='scatter', grid = True).set_title('Соотношение стоимости и общей площади');
plt.xlabel("Стоимость");
plt.ylabel("Площадь, кв.м.");
# Out:
# 0.7811152618156472

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>❌Комментарий ревьюера:</b>
#
# Напоминаю, что каждый график и оси на нем необходимо подписывать</div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔁Комментарий студента:</b>
# Подписал всё, до чего дотянулся)
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %% [markdown]
# Существует положительная корреляция между размером квартиры и её стоимостью.

# %%
print(data['last_price'].corr(data['living_area']))
data.plot(x='last_price', y='living_area', kind='scatter', alpha = 0.3, grid = True).set_title('Соотношение стоимости и жилой площади');
plt.xlabel("Стоимость");
plt.ylabel("Жилая площадь, кв.м.");
# Out:
# 0.6939692300799093

# %% [markdown]
# Хуже прослеживается зависимость размера жилой площади и цены.

# %%
print(data['last_price'].corr(data['kitchen_area']))
data.plot(x='last_price', y='kitchen_area', kind='scatter', alpha = 0.3, grid = True).set_title('Соотношение стоимости и площади кухни');
plt.xlabel("Стоимость");
plt.ylabel("Площадь кухни, кв.м.");
# Out:
# 0.6170765386193541

# %% [markdown]
# Точно так же с размером кухни - зависимость не сильная.

# %%
#было
print(data['last_price'].corr(data['rooms']))
data.plot(x='rooms', y='last_price', kind='scatter', alpha = 0.3, grid = True).set_title('Соотношение стоимости и количества комнат');
plt.xlabel("Стоимость");
plt.ylabel("Количество комнат");
#добавил после комментария "На двух визуализациях выше лучше также использовать барплот, с предварительным формированием сводной таблицы"
data.pivot_table(index='rooms', values='last_price').plot(kind='bar', grid = True).set_title('Соотношение стоимости и комнат');
plt.ylabel("Стоимость");
# Out:
# 0.5077095672923402

# %% [markdown]
# Количество комнат почти не влияют на стоимость квартиры. В среднем ценовом диапазоне лежат квартиры с разным количеством комнат.

# %%
# тип этажа - не цифра, нельзя проверить корреляцию.
data.pivot_table(index='floor_type', values='last_price', aggfunc='median').plot(kind='bar', grid = True).set_title('Соотношение стоимости и типа этажа');
plt.ylabel("Стоимость");

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>🔁Комментарий ревьюера:</b>
#
# На двух визуализациях выше лучше также использовать барплот, с предварительным формированием сводной таблицы</div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔁Комментарий студента:</b>
# Выше - это про количество комнат и тип этажа? (тип этажа и был сделан через pivot_table, потому что буквы)
# в количество комнат добавил pivot_table, но получился странный график - пока закомментировал.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍 Почему график тебе показался странным? Все ок. Просто нужно дополнительно отсечь аномальные значения в комнатности. Много ли  у нас квартир с количеством комнат более 5? </div>

# %% [markdown]
# Из графика видно, что квартиры на первом этаже самые дешевые, на последнем - подороже.
# Но квартиры на других этажах дороже остальных, в среднем, на 600 тысяч

# %%
#print(plt.bar(data['day_expo'], data['last_price'])) #мой код
data.pivot_table(index='day_expo', values='last_price', aggfunc='median').plot(grid = True); #код ревьювера

# %% [markdown]
# Странное замечание, что по субботам выставляют дешёвые объявления.

# %%
#print(plt.bar(data['month_expo'], data['last_price']));
data.pivot_table(index='month_expo', values='last_price', aggfunc='median').plot(grid = True);

# %% [markdown]
# В мае и июне цены ниже, но как мы помним - и объявлений меньше.

# %%
#print(plt.bar(data['year_expo'], data['last_price']));
data.pivot_table(index='year_expo', values='last_price', aggfunc='median').plot(grid = True);

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>❌Комментарий ревьюера:</b>
#
# А что нам строит метод `bar()`? Ниже построил барплот, который показывает актуальные значения</div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔁Комментарий студента:</b>
# Если честно, я не понял что строит мой bar. На твоём способе график противоположный, цена в 2014 была выше всего - и я это проверил простым перебором. Почему тогда мой способ показал обратное значение, будто в 2014 цена была ниже всего?
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  Нужно подробнее изучить метод, который ты использовал и какие значения он берет.</div>

# %%
# код ревьюера
data.pivot_table(index='year_expo', values='last_price', aggfunc='median').plot(kind='bar', grid = True);

# %% [markdown]
# После кризиса 2014 цены опустились и находились примерно на одном уровне 4 года. К 2019 начался рост.

# %% [markdown]
# Вывод: на цену однозначно влияют `размер квартиры` - чем больше квартира, тем больше и стоимость.
# Объявления, выложенные в `выходные` имеют цену ниже обычной.
# Квартиры на `первом` этаже дешевле всего.

# %% [markdown]
# # 4.3 Вычисляем среднюю цену одного квадратного метра в 10 населённых пунктах

# %%
top_ten = data.pivot_table(index = 'locality_name', values = 'sqm_price', aggfunc=['count', 'mean'])
top_ten.columns = ['count', 'mean']
top_ten = top_ten.sort_values('count', ascending = False)
top_ten.head(10)
# Out:
#                  count           mean
# locality_name
# Санкт-Петербург  15428  112135.252511
# Мурино             584   86017.231919
# Кудрово            469   95261.963450
# Шушары             438   78529.235071
# Всеволожск         397   68719.320400
# Пушкин             361  102874.295312
# Колпино            337   75443.972838
# Парголово          326   90205.423758
# Гатчина            307   68746.146763
# Выборг             235   58238.143141

# %%
top_ten.sort_values('mean', ascending=False)
top_ten.head(1)
# Out:
#                  count           mean
# locality_name
# Санкт-Петербург  15428  112135.252511

# %%
top_ten_min = top_ten.sort_values('mean', ascending=True)
top_ten_min.head(1)
# Out:
#                count          mean
# locality_name
# Старополье         3  11206.221198

# %% [markdown]
# Вывод: Самый дорогой квадратный метр - в Санкт-Петербурге, а самый дешевый - в Старополье, деревне в 140км от центра.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера:</b>
# Все верно</div>

# %% [markdown]
# # 4.4 Вычислим среднюю цену каждого километра.

# %%
data['center_distance_km'] = data['center_distance_km'].fillna(9999999)
data['center_distance_km'] = data['center_distance_km'].astype('int')
spb_km = data.query('locality_name == "Санкт-Петербург" and center_distance_km !=9999999').pivot_table(index = 'center_distance_km', values = 'sqm_price', aggfunc = 'mean')
spb_km.plot().set_title('Зависимость стоимости от удаленности от центра');
plt.ylabel("Стоимость 1 кв.м.");
plt.xlabel("Удаленность от центра, км.");
spb_km
# Out:
#                         sqm_price
# center_distance_km
# 0                   204865.512151
# 1                   144823.552337
# 2                   136376.730457
# 3                   118443.445743
# 4                   127238.682305
# 5                   134574.582924
# 6                   140788.107944
# 7                   141993.093595
# 8                   123887.261549
# 9                   113454.393689
# 10                  112685.087759
# 11                  108031.116437
# 12                  107474.500487
# 13                  108050.546695
# 14                  104176.291952
# 15                  104228.433148
# 16                  100547.960943
# 17                   97015.343101
# 18                   96415.427716
# 19                   98658.388032
# 20                  103056.539879
# 21                   94509.188656
# 22                   91330.425050
# 23                   91490.816313
# 24                   85736.904595
# 25                   91531.371618
# ...

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>❌Комментарий ревьюера:</b>
#
# В п.3 мы добавляли столбец с расстоянием до центра в километрах. Его и нужно тут использовтаь) И не забывай подпсывать графики)</div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
# Исправил ✔ подписал
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %% [markdown]
# Вывод: Закономерно, чем ближе к центру - тем дороже. Исключением является расстояние 27 км от центра, вероятно, там расположены коттеджные поселки или другая элитная недвижимость.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера:</b>
#
# Вывод правильный и вполне логичный</div>

# %% [markdown]
# ### Общий вывод

# %% [markdown]
# Проведён анализ, в результате которого можно заявить о закономерностях и параметрах, влияющих на стоимость квартир в Санкт-Петербурге и Ленинградской области.
# Обработана полученная база данных:
# * Обработаны пропущенные значения там, где это необходимо,
# * Заменены типы данных на необходимые для удобной работы.
# * Посчитаны и добавлены в таблицу: цена квадратного метра жилья, дни недели, месяцы и годы размещения объявлений, добавлены категории по этажам квартир.
# * Изучены следующие параметры на наличие выбивающихся значений - общая площадь, цена, число комнат, высота потолков. Были определены аномалии в данных параметрах.
#
#
# В процессе изучения 23 тысяч объявлений стало ясно, что **типичное объявление** несёт в себе информацию о **1-2х комнатной** квартире внутри Санкт-Петербурга, размерами около **40 квадратных метров**, с невысокими потолками, зато недалеко от парка, скорее всего в пятиэтажках, советской постройки.
# Стоимость такой квартиры около **4.5 миллионов рублей**.
#
# Выводы по итогам анализа:
#
# * Рынок продаж не стоит, и **в среднем квартира продаётся за `3 месяца`**. В случае, если сделка состоится в течении 1 месяца, то можно говорить о *быстрой продаже*, и в противоположном случае, если объявление не снято в течении 6 месяцев - продажа считается *необычно долгой*.
#
# * На **стоимость** средней квартиры может повлиять её `расположение` относительно центра города, `общая площадь`, `расположение на разных этажах`.
#
# * **Больше всего объявлений** и **самая высокая цена** - в `Санкт-Петербурге`. Самое **дешевое жильё** можно поискать, например, в деревне `Старополье`.
#
# * **Близость к центру** - один из самых ярких показателей цены, который, однако не влияет на цены в элитных посёлках. Там они высоки, как и в центре.
#
# * Чаще объявления публикуются в будние дни (3500 против 1700 в выходные), в феврале-апреле, есть из чего выбрать. В мае объявлений меньше всего.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>❌Комментарий ревьюера:</b>
#
# Здорово, что описал типичную квартиру из объявления. Но вывод должен быть более подробным и содержать в себе еще информацию о том, какая работа была проделана на этапе предобработки.
#
# Человек, заинтересовавшийся твоим проектом, может сразу перейти к выводу, чтобы понять нужно ли ему углубляться в изучение исследования или нет.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
# ✔
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %% [markdown]
# **Чек-лист готовности проекта**
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  открыт файл
# - [x]  файлы изучены (выведены первые строки, метод `info()`, гистограммы и т.д.)
# - [x]  определены пропущенные значения
# - [x]  заполнены пропущенные значения там, где это возможно
# - [x]  есть пояснение, какие пропущенные значения обнаружены
# - [x]  изменены типы данных
# - [x]  есть пояснение, в каких столбцах изменены типы и почему
# - [x]  устранены неявные дубликаты в названиях населённых пунктов
# - [x]  устранены редкие и выбивающиеся значения (аномалии) во всех столбцах
# - [x]  посчитано и добавлено в таблицу: цена одного квадратного метра
# - [x]  посчитано и добавлено в таблицу: день публикации объявления (0 - понедельник, 1 - вторник и т.д.)
# - [x]  посчитано и добавлено в таблицу: месяц публикации объявления
# - [x]  посчитано и добавлено в таблицу: год публикации объявления
# - [x]  посчитано и добавлено в таблицу: тип этажа квартиры (значения — «первый», «последний», «другой»)
# - [x]  посчитано и добавлено в таблицу: расстояние в км до центра города
# - [x]  изучены и описаны следующие параметры:
#         - общая площадь;
#         - жилая площадь;
#         - площадь кухни;
#         - цена объекта;
#         - количество комнат;
#         - высота потолков;
#         - этаж квартиры;
#         - тип этажа квартиры («первый», «последний», «другой»);
#         - общее количество этажей в доме;
#         - расстояние до центра города в метрах;
#         - расстояние до ближайшего аэропорта;
#         - расстояние до ближайшего парка;
#         - день и месяц публикации объявления
# - [x]  построены гистограммы для каждого параметра
# - [x]  выполнено задание: "Изучите, как быстро продавались квартиры (столбец days_exposition). Этот параметр показывает, сколько дней «висело» каждое объявление.
#     - Постройте гистограмму.
#     - Посчитайте среднее и медиану.
#     - В ячейке типа markdown опишите, сколько обычно занимает продажа. Какие продажи можно считать быстрыми, а какие — необычно долгими?"
# - [x]  выполнено задание: "Какие факторы больше всего влияют на общую (полную) стоимость объекта? Постройте графики, которые покажут зависимость цены от указанных ниже параметров. Для подготовки данных перед визуализацией вы можете использовать сводные таблицы."
#         - общей площади;
#         - жилой площади;
#         - площади кухни;
#         - количество комнат;
#         - типа этажа, на котором расположена квартира (первый, последний, другой);
#         - даты размещения (день недели, месяц, год);
# - [x]  выполнено задание: "Посчитайте среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений. Выделите населённые пункты с самой высокой и низкой стоимостью квадратного метра. Эти данные можно найти по имени в столбце `locality_name`."
# - [x]  выполнено задание: "Ранее вы посчитали расстояние до центра в километрах. Теперь выделите квартиры в Санкт-Петербурге с помощью столбца `locality_name` и вычислите среднюю цену каждого километра. Опишите, как стоимость объектов зависит от расстояния до центра города."
# - [X]  в каждом этапе есть промежуточные выводы
# - [X]  есть общий вывод
